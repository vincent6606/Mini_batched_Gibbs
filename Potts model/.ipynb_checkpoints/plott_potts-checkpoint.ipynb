# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("paper", font_scale=1.5)
flatui = ["#0a4d8c", "#ba0c2f", "#49a343", "#6E10FF", "#DE4C0B", "#0095c8", "#4d2177", "#7c3a2d"]
# https://color.adobe.com/zh/create/color-wheel/?basfrom matplotlib import rc
sns.palplot(flatui)

# %%
error = np.genfromtxt('MGPMH_errors_10_20_1000000.csv',delimiter=',')

# %%
error.shape
# Out:
# (3, 500001)

# %%
k = error
k = np.sort(k,0)

# %%
error[:,0]
# Out:
# array([ 15.18881376,   0.75944069,  60.75525503])

# %%
import matplotlib.lines as lines
with sns.axes_style("white"):
    fig = plt.figure(figsize=(8, 5.5))
    ax  = fig.add_subplot(111)
    for i in range(error.shape[0]):
        line = k[i,-300000:]
        plt.plot(line,color=flatui[i],label="$\lambda = $ {0:.4f}".format(error[i,0]))

    plt.xlabel("iterations", size=15)
    plt.ylabel("Error in Marginals", size=15)
#     plt.title('50 by 50 Potts model')
    plt.legend(loc='upper right')
    plt.grid(linestyle='dotted')
    plt.tight_layout(pad=1, w_pad=1, h_pad=1)

    plt.savefig("Marginals_{}.pdf".format('50'), bbox_inches='tight')
    plt.show()

# %%
gibbs_error = np.genfromtxt('Gibbs_errors_10_20_1000000.csv ',delimiter=',')

# %%
gibbs_error.shape
# Out:
# (3, 100000)

# %%
gibbs_error[0,0]
# Out:
# 0.89442719099991619

# %%
import matplotlib.lines as lines
with sns.axes_style("white"):
    fig = plt.figure(figsize=(8, 5.5))
    ax  = fig.add_subplot(111)
    for i in range(gibbs_error.shape[0]):
        line = gibbs_error[i,-100000:]
        plt.plot(line,color=flatui[i],label="trial {}".format(i))

    for i in range(error.shape[0]):
        line = k[i,-100000:]
        plt.plot(line,color=flatui[3+i],label="$\lambda = $ {0:.4f}".format(error[i,0]))
    plt.xlabel("iterations", size=15)
    plt.ylabel("Error in Marginals", size=15)
#     plt.title('50 by 50 Potts model')
    plt.legend(loc='upper right')
    plt.grid(linestyle='dotted')
    plt.tight_layout(pad=1, w_pad=1, h_pad=1)

    plt.savefig("Marginals_{}.pdf".format('50'), bbox_inches='tight')
    plt.show()

# %%
# !ls
# Out:
# Gibbs_errors_10_20_1000000.csv    errors_151020_50_1000.csv
# Gibbs_errors_10_50_100.csv        errors_5_50.csv
# Gibbs_errors_151020_20_100000.csv errors_5_50_100000.csv
# Gibbs_potts.py                    plott_potts.ipynb
# MGPMH_errors_10_20_1000000.csv    potts.py
# Marginals_50.pdf                  potts.py.lprof
# errors1_5.csv                     potts_video.py
# errors_151020_20_100000.csv       potts_video.py.lprof
# errors_151020_20_1000000.csv      run.sh
# errors_151020_20_500000.csv       test.py
